# %%
# Librerías
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import kagglehub
path = kagglehub.dataset_download("fedesoriano/company-bankruptcy-prediction")


import pandas as pd
df = pd.read_csv(path+ "/data.csv")

# %%
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
# Limipar duplicados
df.drop_duplicates

# Limpiar nombres de columnas 
df.columns = df.columns.str.strip().str.replace(" ", "")

# Eliminar valores nulos 
df.dropna(inplace=True)

# Calcular la matriz de correlación
corr_matrix = df.corr()

# Obtener la correlación de cada variable con 'Bankrupt?'
correlation_with_target = corr_matrix["Bankrupt?"].abs().sort_values(ascending=False)

# Seleccionar las 10 variables más correlacionadas (excluyendo 'Bankrupt?' en sí)
top_features = correlation_with_target[1:11]  
print(top_features)

top_features_array = top_features.index.to_numpy()
print(f"Array de columnas: ",top_features_array)
# Out:
# NetIncometoTotalAssets                               0.315457
# ROA(A)beforeinterestand%aftertax                     0.282941
# ROA(B)beforeinterestanddepreciationaftertax          0.273051
# ROA(C)beforeinterestanddepreciationbeforeinterest    0.260807
# Networth/Assets                                      0.250161
# Debtratio%                                           0.250161
# PersistentEPSintheLastFourSeasons                    0.219560
# RetainedEarningstoTotalAssets                        0.217779
# Netprofitbeforetax/Paid-incapital                    0.207857
# PerShareNetprofitbeforetax(Yuan¥)                    0.201395
# Name: Bankrupt?, dtype: float64
# Array de columnas:  ['NetIncometoTotalAssets' 'ROA(A)beforeinterestand%aftertax'
#  'ROA(B)beforeinterestanddepreciationaftertax'
#  'ROA(C)beforeinterestanddepreciationbeforeinterest' 'Networth/Assets'
#  'Debtratio%' 'PersistentEPSintheLastFourSeasons'
# ...

# %%
df_export = df[top_features_array]
df_export['bankrupt'] = df['Bankrupt?']
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_15512\5280031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['bankrupt'] = df['Bankrupt?']

# %%
df_export
# Out:
#       NetIncometoTotalAssets  ROA(A)beforeinterestand%aftertax  \
# 0                   0.716845                          0.424389
# 1                   0.795297                          0.538214
# 2                   0.774670                          0.499019
# 3                   0.739555                          0.451265
# 4                   0.795016                          0.538432
# ...                      ...                               ...
# 6814                0.799927                          0.539468
# 6815                0.799748                          0.538269
# 6816                0.797778                          0.533744
# 6817                0.811808                          0.559911
# 6818                0.815956                          0.570105
#
#       ROA(B)beforeinterestanddepreciationaftertax  \
# 0                                        0.405750
# 1                                        0.516730
# 2                                        0.472295
# ...

# %%
df_export.to_csv("clean_data.csv")
